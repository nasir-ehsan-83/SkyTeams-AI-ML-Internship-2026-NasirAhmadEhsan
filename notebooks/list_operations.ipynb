# %% [markdown]
# ## Implementation of common list algorithms in Python

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# ## Reverse List

# %%
from src.python_fundamental.list_operations.reverse_list import reverse

reverse([1,2,3,4,5])

# %% [markdown]
# ## Insertion Sort

# %%
from src.python_fundamental.list_operations.sort import insertion_sort

arr = [5,3,1,4]

insertion_sort(arr)

arr
# Out:
# [1, 3, 4, 5]
